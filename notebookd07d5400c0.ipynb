# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from PIL import Image, ImageEnhance
#read the image
im = Image.open("/kaggle/input/dddddd/download (15).jpg")
#image brightness enhancer
enhancer = ImageEnhance.Brightness(im)
factor = 1 #gives original image
im_output = enhancer.enhance(factor)
im_output.save('asli.png')
factor = 0.5 #darkens the image
im_output = enhancer.enhance(factor)
im_output.save('gelap.png')
factor = 1.5 #brightens the image
im_output = enhancer.enhance(factor)
im_output.save('cerah.png')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('/kaggle/input/qqqqqqq/de399670-e403-419a-8096-8058c6a509af.jpg',0)
img_negative = 255 - img
plt.figure(figsize=(15, 15))
plt.subplot(1,2,1)
plt.imshow(img,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_negative,cmap="gray")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
lego_a = cv2.imread('/kaggle/input/fgdggdgdfgg/f4b58cf1-6d75-47f3-895b-2a9700323bb4.jpg',1)
lego_a = cv2.cvtColor(lego_a, cv2.COLOR_BGR2RGB)
lego_b = cv2.imread('/kaggle/input/fgdggdgdfgg/f4b58cf1-6d75-47f3-895b-2a9700323bb4.jpg',1)
lego_b = cv2.cvtColor(lego_b, cv2.COLOR_BGR2RGB)
lego_blending = cv2.addWeighted(lego_a, 0.7, lego_b, 0.5,0)
plt.figure(figsize=(20, 20))
plt.subplot(1,3,1)
plt.imshow(lego_a)
plt.subplot(1,3,2)
plt.imshow(lego_b)
plt.subplot(1,3,3)
plt.imshow(lego_blending)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
lego_a = cv2.imread('/kaggle/input/wewewewewewe/2744069a-6715-48ee-b855-f095f20f8056.jpe',1)
lego_a = cv2.cvtColor(lego_a, cv2.COLOR_BGR2RGB)
lego_b = cv2.imread('/kaggle/input/wewewewewewe/2744069a-6715-48ee-b855-f095f20f8056.jpe',1)
lego_b = cv2.cvtColor(lego_b, cv2.COLOR_BGR2RGB)
lego_blending = cv2.addWeighted(lego_a, 0.7, lego_b, 0.5,0)
plt.figure(figsize=(20, 20))
plt.subplot(1,3,1)
plt.imshow(lego_a)
plt.subplot(1,3,2)
plt.imshow(lego_b)
plt.subplot(1,3,3)
plt.imshow(lego_blending)
plt.show()

# %%
img = cv2.imread('/kaggle/input/gagagagagagaa/d02c28ea-d3e5-4feb-aea4-d8b83ad30681.jpg',0)
gamma = 2.5
img_power = img**gamma
plt.figure(figsize=(20, 20))
plt.subplot(1,2,1)
plt.imshow(img,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_power,cmap="gray")
plt.show()

# %%
img = cv2.imread('/kaggle/input/fifififififiififfi/AF1.jpg',1)
kernel = np.ones((3, 3), np.float32) / 9
img_out = cv2.filter2D(img, -1, kernel)
plt.figure(figsize=(20, 20))
plt.subplot(1,2,2)
plt.imshow(img,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_out,cmap="gray")
plt.show()

# %%
img = cv2.imread('/kaggle/input/akuuuuuuuuuuuuuuuuuuuuu/FOTO PROFIL.jpe',0)
c = 255 / np.log10(1 + np.max(img))
img_log = c * (np.log10(img + 1))
img_log = np.array(img_log, dtype = np.uint8)
plt.figure(figsize=(20, 20))
plt.subplot(1,2,1)
plt.imshow(img,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_log,cmap="gray")
plt.show()

# %%
img = cv2.imread('/kaggle/input/hahahahahhahahaa/download (1).jpe',1)
kernel = np.array([
                   [0, -1, 0],
                   [-1, 5,-1],
                   [0, -1, 0]
])
img_out = cv2.filter2D(img, -1, kernel)
plt.figure(figsize=(20, 20))
plt.subplot(1,2,1)
plt.imshow(img,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_out,cmap="gray")
plt.show()
